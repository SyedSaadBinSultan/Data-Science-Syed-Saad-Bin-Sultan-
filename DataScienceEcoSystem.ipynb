# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized.
#
# **Objectives:**
# - We will cover some important langauages used in data science such as Python, SQL, Scala, Julia etc.
# - We will cover some important libraries used in data science such as Plotly, Numpy, Pandas etc.
# - We will cover some important tools used in data science such as Jupyter notebook, STATA, RStudio etc.
# - We will discuss importance and tools for version control such as Git, Git lab and Git Hub.
# - We will cover importance of cloud computing and their advantages.

# %% [markdown]
# ### Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. SQL
# 3. Scala
# 4. Julia

# %% [markdown]
# ### Some of the commonly used libraries used by Data Scientists include:
# 1. Numpy
# 2. Pandas
# 3. Plotly
# 4. Keras
# 5. Tensorflow

# %% [markdown]
# ### Three development environment used in Data Science are:
#
# |Data Science Tools|
# |------------------|
# |Jupyter Notebook|
# |Jupyter Lite|
# |Jupyter Lab|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This a simple arithmetic expression to mutiply then add integers

(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60

200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
#
# Syed Saad Bin Sultan
